# %% [markdown]
# # Задание практики №2 выполнил
#
# *Тугушев Дамир Рустамович*, студент группы *ИКБО-06-19*

# %%
import pandas as pd

df = pd.read_csv('kinopoisk.csv')
df
# Out:
#      film-item-rating-position__position  selection-film-item-poster__rating  \
# 0                                      1                                 9.1
# 1                                      2                                 9.1
# 2                                      3                                 8.6
# 3                                      4                                 8.6
# 4                                      5                                 8.6
# ..                                   ...                                 ...
# 245                                  246                                 7.7
# 246                                  247                                 7.9
# 247                                  248                                 8.0
# 248                                  249                                 7.8
# 249                                  250                                 8.2
#
#           selection-film-item-meta__name  rating__value rating__count
# 0                           Зеленая миля            8.9       701 104
# 1                      Побег из Шоушенка            8.9       790 958
# 2    Властелин колец: Возвращение короля            8.8       488 761
# 3          Властелин колец: Две крепости            8.8       476 404
# 4       Властелин колец: Братство Кольца            8.8       527 358
# ..                                   ...            ...           ...
# 245                            Марсианин            8.0       424 314
# 246                                Радио            8.0        21 625
# 247             Ведьмина служба доставки            8.0        71 204
# 248          Константин: Повелитель тьмы            8.0       350 411
# 249                            Капернаум            8.0       128 685
#
# [250 rows x 5 columns]

# %%
mapping = {
    'film-item-rating-position__position': 'position',
    'selection-film-item-poster__rating': 'poster_rating',
    'selection-film-item-meta__name': 'name',
    'rating__value': 'rating',
    'rating__count': 'count',
}

df = df.rename(columns=mapping)
df = df.drop(columns='position')
df
# Out:
#      poster_rating                                 name  rating    count
# 0              9.1                         Зеленая миля     8.9  701 104
# 1              9.1                    Побег из Шоушенка     8.9  790 958
# 2              8.6  Властелин колец: Возвращение короля     8.8  488 761
# 3              8.6        Властелин колец: Две крепости     8.8  476 404
# 4              8.6     Властелин колец: Братство Кольца     8.8  527 358
# ..             ...                                  ...     ...      ...
# 245            7.7                            Марсианин     8.0  424 314
# 246            7.9                                Радио     8.0   21 625
# 247            8.0             Ведьмина служба доставки     8.0   71 204
# 248            7.8          Константин: Повелитель тьмы     8.0  350 411
# 249            8.2                            Капернаум     8.0  128 685
#
# [250 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.displot(df['poster_rating'])

df['poster_rating']
# Out:
# 0      9.1
# 1      9.1
# 2      8.6
# 3      8.6
# 4      8.6
#       ...
# 245    7.7
# 246    7.9
# 247    8.0
# 248    7.8
# 249    8.2
# Name: poster_rating, Length: 250, dtype: float64

# %%
sns.displot(df['rating'])

df['rating']
# Out:
# 0      8.9
# 1      8.9
# 2      8.8
# 3      8.8
# 4      8.8
#       ...
# 245    8.0
# 246    8.0
# 247    8.0
# 248    8.0
# 249    8.0
# Name: rating, Length: 250, dtype: float64

# %%
sns.distplot(df['rating'])
sns.distplot(df['poster_rating'])
# Out:
# C:\Users\0dami\AppData\Local\Temp\ipykernel_13516\3231847291.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rating'])
# C:\Users\0dami\AppData\Local\Temp\ipykernel_13516\3231847291.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['poster_rating'])
# <AxesSubplot:xlabel='poster_rating', ylabel='Density'>

# %%
sns.scatterplot(df)
# Out:
# <AxesSubplot:>
